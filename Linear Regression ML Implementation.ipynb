# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Lets load the Boston House Pricing Dataset

# %%
#loading the boston dataset from sklearn library
from sklearn.datasets import load_boston

# %%
boston=load_boston()
# Out:
# c:\python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
boston.keys()   #points on which we are studying
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
# Lets check the description of the dataset
print(boston.DESCR)
print(boston.feature_names)
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
print(boston.data)
# Out:
# [[6.3200e-03 1.8000e+01 2.3100e+00 ... 1.5300e+01 3.9690e+02 4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9690e+02 9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9283e+02 4.0300e+00]
#  ...
#  [6.0760e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 5.6400e+00]
#  [1.0959e-01 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9345e+02 6.4800e+00]
#  [4.7410e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 7.8800e+00]]

# %%
print(boston.target)    #to find the price as per features
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
# ...

# %%
print(boston.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %% [markdown]
# ## Preparing The Dataset

# %%
#converting the dataset into dataframe and assigning the column names acc to feature_name
#These are the independent features
dataset=pd.DataFrame(boston.data,columns=boston.feature_names)

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# <h3>Exploratory Data Analysis ¶</h3>

# %%
dataset.shape
# Out:
# (506, 13)

# %%
 #Creating a new column as price , This is an output feature
dataset['Price']=boston.target

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %% [markdown]
# <h3>The lower and upper limit is calculated as – Lower Limit = Q1 - 1.5*IQR Upper Limit = Q3 + 1.5*IQR The values below and above these limits are considered outliers and the minimum and maximum values are calculated from the points which lie under the lower and upper limit.</h3>

# %%
# find lower and upperlimit of all columns
for i in dataset.columns:
    print(i)
    print(dataset[i].quantile(0.25))
    print(dataset[i].quantile(0.75))
    print("")
# Out:
# CRIM
# 0.08204499999999999
# 3.6770825
#
# ZN
# 0.0
# 12.5
#
# INDUS
# 5.19
# 18.1
#
# CHAS
# 0.0
# 0.0
#
# NOX
# 0.449
# 0.624
#
# RM
# 5.8854999999999995
# 6.6235
#
# AGE
# 45.025
# 94.07499999999999
#
# DIS
# 2.100175
# 5.1884250000000005
#
# RAD
# 4.0
# 24.0
#
# TAX
# 279.0
# 666.0
#
# PTRATIO
# 17.4
# 20.2
#
# B
# 375.3775
# 396.225
#
# LSTAT
# 6.949999999999999
# 16.955000000000002
#
# Price
# 17.025
# 25.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
dataset.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# Price      float64
# dtype: object

# %%
# Summarizing The Stats of the data
dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# Check the missing Values
dataset.isnull().sum()
#there is no missing value in the data
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %%
# Finidng the kurtosis of independent varibales
dataset.kurt()
# Out:
# CRIM       37.130509
# ZN          4.031510
# INDUS      -1.233540
# CHAS        9.638264
# NOX        -0.064667
# RM          1.891500
# AGE        -0.967716
# DIS         0.487941
# RAD        -0.867232
# TAX        -1.142408
# PTRATIO    -0.285091
# B           7.226818
# LSTAT       0.493240
# Price       1.495197
# dtype: float64

# %%
# Finding the skewness of independent variables
dataset.skew()
# Out:
# CRIM       5.223149
# ZN         2.225666
# INDUS      0.295022
# CHAS       3.405904
# NOX        0.729308
# RM         0.403612
# AGE       -0.598963
# DIS        1.011781
# RAD        1.004815
# TAX        0.669956
# PTRATIO   -0.802325
# B         -2.890374
# LSTAT      0.906460
# Price      1.108098
# dtype: float64

# %%
# Finding the variance of independent variables
dataset.var()
# Out:
# CRIM          73.986578
# ZN           543.936814
# INDUS         47.064442
# CHAS           0.064513
# NOX            0.013428
# RM             0.493671
# AGE          792.358399
# DIS            4.434015
# RAD           75.816366
# TAX        28404.759488
# PTRATIO        4.686989
# B           8334.752263
# LSTAT         50.994760
# Price         84.586724
# dtype: float64

# %%
# Ploting the boxplot of all the input varibales
plt.rcParams['figure.figsize'] = [10, 7]
plt.title("Boxplot of CRIM")
plt.boxplot(dataset)
plt.show()

# %%
#Box Plot, Distribution Plot and Scatter Plot for PTRATIO
import seaborn as sns
plt.figure(figsize=(20,3))

plt.subplot(1,3,1)
sns.boxplot(dataset.PTRATIO,color='#005030')
plt.title('Box Plot of PTRATIO')

plt.subplot(1,3,2)
sns.distplot(a=dataset.PTRATIO,color='#500050')
plt.title('Distribution Plot of PTRATIO')

plt.subplot(1,3,3)
sns.scatterplot(dataset.PTRATIO,dataset.Price)
plt.title('Scatter Plot of PTRATIO vs Price')

plt.show()
#This shows that it is left skewed
# Out:
# c:\python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <h4> Observations: </h4>
#     <p> - "PTRATIO" is normally distributed. <br>
#     - This shows that it is left skewed <br>
#     - It has no outliers</p>

# %% [markdown]
# <h3> Analyzing The Correlated Features</h3>

# %%
#Correlation
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# <h4> Observation </h4>
# <p> - Through this, we are checking the correlation b/w independent variables and in b/w independent and output variable. <br>
#     - If there is high correlation b/w independent variables then we can remove one of independent variables that is also known as multicollinearity <br>
# - But in this dataset, there is no highly correlated features. </p>

# %%
# to create a pair plot 
# It shows the realation between independent variables or indepdendent and dependent variable through scatter plot and histogram.
import seaborn as sns
sns.pairplot(dataset)

# %%
import seaborn as sns
plt.scatter(dataset['CRIM'],dataset['Price'])
plt.xlabel("Crime Rate")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# <h4> Observation: </h4>
# <p> - This is a scatter plot between the independent variable Crime Rate and output variable Price.<br>
#     - Crime rate and Price are inversely proportional. </p

# %%
#plt b/w rm and price
plt.scatter(dataset['RM'],dataset['Price'])
plt.xlabel("RM")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# <h4> Observation: </h4>
# <p> - This is a scatter plot between the independent variable RM and output variable Price.<br>
#     - RM and Price are directly proportional. </p>

# %%
#to create a linear regression line 
sns.regplot(x="RM",y="Price",data=dataset)
# Out:
# <AxesSubplot:xlabel='RM', ylabel='Price'>

# %% [markdown]
# <h3> Observation: </h3>
# <p> - This is a regression plot between RM and Price with the regression line. <br>
#     - Some variation is also there, but is also directly proportional aligned to the line. <br>
#     - Data is densely distributed showing high correlation. </p>

# %%
sns.regplot(x="LSTAT",y="Price",data=dataset)
# Out:
# <AxesSubplot:xlabel='LSTAT', ylabel='Price'>

# %% [markdown]
# <h4> Observation: </h4>
# <p> -This is a regression plot between LSTAT and Price with the regression line. <br>
# - Some variation is also there, but is also inversely proportional aligned to the line. <br>
# - Data is densely distributed. </p>

# %%
sns.regplot(x="CHAS",y="Price",data=dataset)
# Out:
# <AxesSubplot:xlabel='CHAS', ylabel='Price'>

# %% [markdown]
# <h4> Observation: </h4>
# <p> -This is a regression plot between CHAS and Price with the regression line. <br>
# - Data is distributed only along the extreme boundary points. </p>

# %%
sns.regplot(x="PTRATIO",y="Price",data=dataset)
# Out:
# <AxesSubplot:xlabel='PTRATIO', ylabel='Price'>

# %% [markdown]
# <h4> Observation: </h4>
# <p> -This is a regression plot between PTRATIO and Price with the regression line. <br>
# - Variation is there, but is also inversely proportional not properly aligned to the line. <br> </p>

# %%
# Plotting the heatmap of correlation between features
corr=dataset.corr()
plt.figure(figsize=(14,14))
sns.heatmap(corr, cbar=False, square= True, fmt='.2%', annot=True, cmap='Greens')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h4> Observation: </h4>
# <p>- Postive sign implies postive correlation between two features whereas Negative sign implies negative correlation between two features.<br>
# - To know which features have good correlation with our dependent variable PRICE and can help in having good predictions.<br>
# - It is  observed that INDUS, RM, TAX, PTRATIO and LSTAT shows some good correaltion with PRICE. </p>

# %%
# Independent and Dependent Features
X=dataset.iloc[:,:-1]      #removing last column, output variable
y=dataset.iloc[:,-1]    #take all data points execpt of last column

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: Price, Length: 506, dtype: float64

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %% [markdown]
# <p> -Random_state is the random number generator <br>
#     -If you don't specify the random_state in the code, then every time you run the code a new random value is generated and the train and test datasets would have different values each time. </p>

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 5     0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622   3.0  222.0
# 116   0.13158   0.0  10.01   0.0  0.547  6.176  72.5  2.7301   6.0  432.0
# 45    0.17142   0.0   6.91   0.0  0.448  5.682  33.8  5.1004   3.0  233.0
# 16    1.05393   0.0   8.14   0.0  0.538  5.935  29.3  4.4986   4.0  307.0
# 468  15.57570   0.0  18.10   0.0  0.580  5.926  71.0  2.9084  24.0  666.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...   ...    ...
# 106   0.17120   0.0   8.56   0.0  0.520  5.836  91.9  2.2110   5.0  384.0
# 270   0.29916  20.0   6.96   0.0  0.464  5.856  42.1  4.4290   3.0  223.0
# 348   0.01501  80.0   2.01   0.0  0.435  6.635  29.7  8.3440   4.0  280.0
# 435  11.16040   0.0  18.10   0.0  0.740  6.629  94.6  2.1247  24.0  666.0
# 102   0.22876   0.0   8.56   0.0  0.520  6.405  85.4  2.7147   5.0  384.0
#
#      PTRATIO       B  LSTAT
# 5       18.7  394.12   5.21
# ...

# %%
X_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 173  0.09178   0.0   4.05   0.0  0.510  6.416   84.1  2.6463   5.0  296.0
# 274  0.05644  40.0   6.41   1.0  0.447  6.758   32.9  4.0776   4.0  254.0
# 491  0.10574   0.0  27.74   0.0  0.609  5.983   98.8  1.8681   4.0  711.0
# 72   0.09164   0.0  10.81   0.0  0.413  6.065    7.8  5.2873   4.0  305.0
# 452  5.09017   0.0  18.10   0.0  0.713  6.297   91.8  2.3682  24.0  666.0
# ..       ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 441  9.72418   0.0  18.10   0.0  0.740  6.406   97.2  2.0651  24.0  666.0
# 23   0.98843   0.0   8.14   0.0  0.538  5.813  100.0  4.0952   4.0  307.0
# 225  0.52693   0.0   6.20   0.0  0.504  8.725   83.0  2.8944   8.0  307.0
# 433  5.58107   0.0  18.10   0.0  0.713  6.436   87.9  2.3158  24.0  666.0
# 447  9.92485   0.0  18.10   0.0  0.740  6.251   96.6  2.1980  24.0  666.0
#
#      PTRATIO       B  LSTAT
# 173     16.6  395.50   9.04
# ...

# %%
# Standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
#standardising the dataset in order to make it scale free.

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))
# wb mode: write byte mode.

# %% [markdown]
# <p>Python pickle module is used for serializing and de-serializing python object structures. The process to converts any kind of python objects (list, dict, etc.) into byte streams (0s and 1s) is called pickling or serialization or flattening or marshalling.
# Pickiling of data makes deployment of our dataset easier on various platforms.</p>

# %%
X_train
# Out:
# array([[-0.41425879, -0.50512499, -1.29214218, ...,  0.18727079,
#          0.39651419, -1.01531611],
#        [-0.40200818, -0.50512499, -0.16208345, ..., -0.21208981,
#          0.3870674 , -0.05366252],
#        [-0.39721053, -0.50512499, -0.60948856, ..., -0.16771641,
#          0.42854113, -0.31132373],
#        ...,
#        [-0.41604586,  3.03838247, -1.3166773 , ..., -0.56707702,
#          0.35987906, -0.90549329],
#        [ 0.92611293, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.87841346,  1.52750437],
#        [-0.39030549, -0.50512499, -0.37135358, ...,  1.16348561,
#         -3.32828832, -0.25218837]])

# %%
X_test
# Out:
# array([[-0.406801  , -0.50512499, -1.02225586, ..., -0.74457062,
#          0.41241246, -0.47605794],
#        [-0.41105674,  1.26662874, -0.68165068, ..., -0.30083661,
#          0.42854113, -1.25185755],
#        [-0.4051199 , -0.50512499,  2.39678516, ...,  0.8084984 ,
#          0.35031705,  0.79535229],
#        ...,
#        [-0.35439903, -0.50512499, -0.71195877, ..., -0.38958342,
#          0.25688594, -1.09697922],
#        [ 0.25423453, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.98970133,  0.53487511],
#        [ 0.77732457, -0.50512499,  1.00549958, ...,  0.8528718 ,
#          0.33199949,  0.56585078]])

# %%
y_train
# Out:
# 5      28.7
# 116    21.2
# 45     19.3
# 16     23.1
# 468    19.1
#        ...
# 106    19.5
# 270    21.1
# 348    24.5
# 435    13.4
# 102    18.6
# Name: Price, Length: 354, dtype: float64

# %%
y_test
# Out:
# 173    23.6
# 274    32.4
# 491    13.6
# 72     22.8
# 452    16.1
#        ...
# 441    17.1
# 23     14.5
# 225    50.0
# 433    14.3
# 447    12.6
# Name: Price, Length: 152, dtype: float64

# %% [markdown]
# ## Model Training

# %% [markdown]
# <h1> Random Forest Regression Technique </h1>

# %%
#importing random forest regresser.
from sklearn.ensemble import RandomForestRegressor

# %%
regression1=RandomForestRegressor()

# %%
regression1.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
# on which parameters the model has been trained
regression1.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Prediction With Test Data
reg_pred=regression1.predict(X_test)

# %%
reg_pred
# Out:
# array([22.467, 30.413, 16.028, 23.798, 17.509, 21.687, 19.938, 14.739,
#        21.319, 20.898, 20.425, 20.222,  7.528, 22.051, 19.223, 25.184,
#        18.423,  8.258, 45.53 , 15.487, 24.148, 23.488, 14.525, 23.266,
#        15.682, 14.97 , 21.542, 13.996, 19.965, 20.774, 19.763, 23.237,
#        28.902, 19.578, 14.299, 15.835, 33.666, 19.186, 21.454, 24.315,
#        18.667, 29.775, 45.205, 19.558, 22.247, 13.45 , 15.671, 24.362,
#        18.639, 28.822, 21.436, 33.914, 18.016, 26.466, 46.52 , 22.152,
#        15.644, 32.105, 21.937, 20.805, 25.771, 33.762, 29.216, 18.713,
#        27.69 , 16.675, 13.502, 22.924, 29.128, 14.779, 20.108, 27.51 ,
#        10.046, 22.051, 22.257,  6.962, 20.183, 46.032, 11.508, 12.718,
#        21.503, 11.768, 20.238,  9.183, 20.669, 26.7  , 15.563, 23.277,
#        23.872, 17.85 , 22.173,  7.435, 20.079, 19.356, 21.836, 19.755,
#        39.266, 11.647, 12.219, 12.043, 20.425, 23.917, 13.614, 20.414,
# ...

# %%
# plot a scatter plot for the prediction
plt.scatter(y_test,reg_pred, color='orange')
# the below output plot has come out to be linearly distributed so, 
# our predicted model is fit till now.

# %%
residuals=y_test-reg_pred

# %%
residuals
# Out:
# 173    1.133
# 274    1.987
# 491   -2.428
# 72    -0.998
# 452   -1.409
#        ...
# 441    3.385
# 23    -0.958
# 225    7.252
# 433   -0.761
# 447   -3.579
# Name: Price, Length: 152, dtype: float64

# %%
# Plot this residuals 
sns.displot(residuals,kind="kde", color='orange')

# %%
# Scatter plot with respect to prediction and residuals
plt.scatter(reg_pred,residuals, color='orange')

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 2.1374999999999997
# 9.516877210526317
# 3.0849436316610905

# %% [markdown]
# #R square and adjusted R square
# Formula
#
# **R^2 = 1 - SSR/SST**
#
#
# R^2=	coefficient of determination
# SSR=	sum of squares of residuals
# SST=	total sum of squares

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# The above value of r square is more towards 1,hence,the model is precise...
# Out:
# 0.8722791324397698

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# The value of adjusted r square must be less than the above r square value.
# Out:
# 0.860247456510183

# %%
#the dataset(first row for example) has been converted into 2-D and the first row has been identified.
boston.data[0].reshape(1,-1)
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#         4.980e+00]])

# %%
#transformation of new data
scaler.transform(boston.data[0].reshape(1,-1))
# Out:
# c:\python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.41709233,  0.29216419, -1.27338003, -0.28154625, -0.16513629,
#          0.34715902, -0.13030059,  0.15267164, -0.97798895, -0.66777595,
#         -1.32142483,  0.42854113, -1.04769976]])

# %%
regression.predict(scaler.transform(boston.data[0].reshape(1,-1)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\programming_language\Data_visualiztion\BostonProject\Linear Regression ML Implementation.ipynb Cell 82 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/programming_language/Data_visualiztion/BostonProject/Linear%20Regression%20ML%20Implementation.ipynb#Y142sZmlsZQ%3D%3D?line=0'>1</a> regression.predict(scaler.transform(boston.data[0].reshape(1,-1)))
#
# NameError: name 'regression' is not defined

# %% [markdown]
# <h2>  Linear Regression Technique </h2>

# %%
#importing linear regresser.
from sklearn.linear_model import LinearRegression

# %%
regression2=LinearRegression()

# %%
regression2.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# print the coefficients and the intercept
print(regression2.coef_)
# Out:
# [-1.10834602  0.80843998  0.34313466  0.81386426 -1.79804295  2.913858
#  -0.29893918 -2.94251148  2.09419303 -1.44706731 -2.05232232  1.02375187
#  -3.88579002]

# %%
print(regression2.intercept_)
# Out:
# 23.01581920903955

# %%
# on which parameters the model has been trained
regression2.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %%
# Prediction With Test Data
reg_pred=regression2.predict(X_test)

# %%
reg_pred
# Out:
# array([28.64896005, 36.49501384, 15.4111932 , 25.40321303, 18.85527988,
#        23.14668944, 17.3921241 , 14.07859899, 23.03692679, 20.59943345,
#        24.82286159, 18.53057049, -6.86543527, 21.80172334, 19.22571177,
#        26.19191985, 20.27733882,  5.61596432, 40.44887974, 17.57695918,
#        27.44319095, 30.1715964 , 10.94055823, 24.02083139, 18.07693812,
#        15.934748  , 23.12614028, 14.56052142, 22.33482544, 19.3257627 ,
#        22.16564973, 25.19476081, 25.31372473, 18.51345025, 16.6223286 ,
#        17.50268505, 30.94992991, 20.19201752, 23.90440431, 24.86975466,
#        13.93767876, 31.82504715, 42.56978796, 17.62323805, 27.01963242,
#        17.19006621, 13.80594006, 26.10356557, 20.31516118, 30.08649576,
#        21.3124053 , 34.15739602, 15.60444981, 26.11247588, 39.31613646,
#        22.99282065, 18.95764781, 33.05555669, 24.85114223, 12.91729352,
#        22.68101452, 30.80336295, 31.63522027, 16.29833689, 21.07379993,
# ...

# %% [markdown]
# ## Assumptions

# %%
# plot a scatter plot for the prediction
plt.scatter(y_test,reg_pred)
# the below output plot has come out to be linearly distributed so, 
# our predicted model is fit till now.

# %% [markdown]
# <h4> Observation: </h4>
# <p>
# - The given output plot has come out to be linearly distributed so,
#  our predicted model is fit till now. </p>

# %%
# Residuals(errors)
residuals=y_test-reg_pred

# %%
residuals
# Out:
# 173    -5.048960
# 274    -4.095014
# 491    -1.811193
# 72     -2.603213
# 452    -2.755280
#          ...
# 441    -0.303672
# 23      1.114059
# 225    10.016575
# 433    -2.382863
# 447    -5.685618
# Name: Price, Length: 152, dtype: float64

# %%
# Plot this residuals 
sns.displot(residuals,kind="kde")

# %% [markdown]
# <h4> Observation: </h4>
# <p>
# - The given output plot has come out to be normally distributed so,
#  our predicted model is fit till now. </p>

# %%
# Scatter plot with respect to prediction and residuals
plt.scatter(reg_pred,residuals)

# %% [markdown]
# <h4> Observation: </h4>
# <p>
# - The given output plot has come out to be uniformly distributed so,
#  our predicted model is fit till now. </p>

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 3.162709871457406
# 21.51744423117721
# 4.6386899261728205

# %% [markdown]
# ## R square and adjusted R square

# %% [markdown]
# Formula
#
# **R^2 = 1 - SSR/SST**
#
#
# R^2	=	coefficient of determination
# SSR	=	sum of squares of residuals
# SST	=	total sum of squares

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.7112260057484932

# %%
# The above value of r square is more towards 1,hence,the model is precise.

# %% [markdown]
# **Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)]**
#
# where:
#
# R2: The R2 of the model
# n: The number of observations
# k: The number of predictor variables

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# The value of adjusted r square must be less than the above r square value.
# Out:
# 0.6840226584639308

# %% [markdown]
# ## New Data Prediction

# %%
boston.data[0].reshape(1,-1)
#the dataset(first row for example) has been converted into 2-D and the first row has been identified.
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#         4.980e+00]])

# %%
#transformation of new data
scaler.transform(boston.data[0].reshape(1,-1))
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.41709233,  0.29216419, -1.27338003, -0.28154625, -0.16513629,
#          0.34715902, -0.13030059,  0.15267164, -0.97798895, -0.66777595,
#         -1.32142483,  0.42854113, -1.04769976]])

# %%
regression.predict(scaler.transform(boston.data[0].reshape(1,-1)))
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([30.08649576])

# %% [markdown]
# <h3> Since, adjusted R^2 value of the Random Forest Regression Technique is greater than the adjusted r^2 value of the Multiple linear Regression Technique. Hence, Random Forest Regression Technique is more efficient. <br>
# So, We are using Random Forest Regression Model for further pickling and deployment. </h3>

# %% [markdown]
# ## Pickling The Model file For Deployment

# %%
#pickling the model by importing the pickle model.
import pickle

# %%
#write byte mode
pickle.dump(regression1,open('regmodel.pkl','wb'))

# %%
#read byte mode
pickled_model=pickle.load(open('regmodel.pkl','rb'))

# %%
# Prediction
# Result
pickled_model.predict(scaler.transform(boston.data[0].reshape(1,-1)))
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([28.182])

# %%
# After this, the model will be deployed and the houses' price will be predicted.
